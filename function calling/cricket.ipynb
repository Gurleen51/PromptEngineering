# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in e:\lib\site-packages (1.2.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import os
from datetime import datetime
from dotenv import load_dotenv  # ✅ for environment variables

# ✅ Load variables from .env file
load_dotenv()

# ✅ Get API key and base URL from environment
API_KEY = os.getenv("CRIC_API_KEY")
BASE_URL = os.getenv("CRIC_BASE_URL")
SAVE_DIR = "cricket_results"
os.makedirs(SAVE_DIR, exist_ok=True)

# ✅ Warn if .env or key missing
if not API_KEY or not BASE_URL:
    raise ValueError("❌ Missing CRIC_API_KEY or CRIC_BASE_URL in .env file!")


def save_and_show_output(filename: str, content: str):
    """Save output to file and display in terminal."""
    path = os.path.join(SAVE_DIR, filename)
    with open(path, "w", encoding="utf-8") as f:
        f.write(content)
    print(f"\n📁 Saved to: {path}\n")
    print("🖥️ Output:\n")
    print(content)


def fetch_data(endpoint: str, params: dict = {}):
    """Generic function to fetch data from the API."""
    try:
        response = requests.get(endpoint, params)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"❌ Error fetching data: {e}")
        return None


def timestamp():
    """Generate timestamp for filenames."""
    return datetime.now().strftime("%Y-%m-%d_%H-%M-%S")


def get_live_matches():
    print("\n📡 Fetching current live matches...")
    url = f"{BASE_URL}/currentMatches"
    data = fetch_data(url, {"apikey": API_KEY, "offset": 0})

    output = "🏏 LIVE MATCHES\n\n"
    if data and data.get("status") == "success":
        for match in data.get("data", []):
            output += f"📌 Match: {match.get('name')}\n"
            output += f"🔄 Status: {match.get('status')}\n"
            output += f"🆚 Teams: {match.get('teams')}\n"
            output += f"📍 Venue: {match.get('venue')}\n"
            output += f"📊 Score: {match.get('score')}\n"
            output += "-" * 40 + "\n"
    else:
        output += "❌ No live match data available.\n"

    save_and_show_output(f"live_matches_{timestamp()}.txt", output)


def get_cric_scores():
    print("\n📊 Fetching cric scores...")
    url = f"{BASE_URL}/cricScore"
    data = fetch_data(url, {"apikey": API_KEY})

    output = "📈 CRIC SCORES\n\n"
    if data and data.get("status") == "success":
        for match in data.get("data", []):
            output += f"📌 Match: {match.get('t1')} vs {match.get('t2')}\n"
            output += f"⚡ Score: {match.get('score')}\n"
            output += f"📝 Status: {match.get('status')}\n"
            output += "-" * 40 + "\n"
    else:
        output += "❌ No score data.\n"

    save_and_show_output(f"cric_scores_{timestamp()}.txt", output)


def get_past_matches():
    print("\n🕓 Fetching past matches...")
    url = f"{BASE_URL}/matches"
    data = fetch_data(url, {"apikey": API_KEY, "offset": 0})

    output = "📜 PAST MATCHES\n\n"
    if data and data.get("status") == "success":
        for match in data.get("data", []):
            output += f"📌 Match: {match.get('name')}\n"
            output += f"📅 Date: {match.get('date')}\n"
            output += f"✅ Status: {match.get('status')}\n"
            output += "-" * 40 + "\n"
    else:
        output += "❌ No past match data.\n"

    save_and_show_output(f"past_matches_{timestamp()}.txt", output)


# 🔁 Call all
get_live_matches()
get_cric_scores()
get_past_matches()
# Out:
# 📡 Fetching current live matches...
#
# 📁 Saved to: cricket_results\live_matches_2025-10-30_13-36-50.txt
#
# 🖥️ Output:
#
# 🏏 LIVE MATCHES
#
# 📌 Match: Zimbabwe vs Afghanistan, 1st T20I
# 🔄 Status: Afghanistan won by 53 runs
# 🆚 Teams: ['Zimbabwe', 'Afghanistan']
# 📍 Venue: Harare Sports Club, Harare
# 📊 Score: [{'r': 180, 'w': 6, 'o': 20, 'inning': 'afghanistan Inning 1'}, {'r': 127, 'w': 10, 'o': 16.1, 'inning': 'Zimbabwe,Afghanistan Inning 1'}]
# ----------------------------------------
# 📌 Match: Bangladesh vs West Indies, 2nd T20I
# 🔄 Status: West Indies won by 14 runs
# 🆚 Teams: ['Bangladesh', 'West Indies']
# 📍 Venue: Bir Sreshtho Flight Lieutenant Matiur Rahman Stadium, Chattogram
# 📊 Score: [{'r': 149, 'w': 9, 'o': 20, 'inning': 'west indies Inning 1'}, {'r': 135, 'w': 8, 'o': 20, 'inning': 'Bangladesh,West Indies Inning 1'}]
# ----------------------------------------
# 📌 Match: Western Australia vs South Australia, 9th Match
# 🔄 Status: Day 3: Tea Break - South Australia lead by 89 runs
# 🆚 Teams: ['Western Australia', 'South Australia']
# 📍 Venue: W.A.C.A. Ground, Perth
# 📊 Score: [{'r': 215, 'w': 10, 'o': 59, 'inning': 'South Australia Inning 1'}, {'r': 307, 'w': 10, 'o': 110.2, 'inning': 'Western Australia Inning 1'}, {'r': 181, 'w': 1, 'o': 66, 'inning': 'South Australia Inning 2'}]
# ----------------------------------------
# 📌 Match: Queensland vs New South Wales, 8th Match
# 🔄 Status: Day 3: 3rd Session - Queensland trail by 201 runs
# 🆚 Teams: ['Queensland', 'New South Wales']
# 📍 Venue: The Gabba, Brisbane
# 📊 Score: [{'r': 429, 'w': 7, 'o': 116.5, 'inning': 'New South Wales Inning 1'}, {'r': 228, 'w': 4, 'o': 67, 'inning': 'Queensland Inning 1'}]
# ----------------------------------------
# 📌 Match: Victoria vs Tasmania, 7th Match
# 🔄 Status: Day 3: Stumps - Tasmania need 327 runs
# 🆚 Teams: ['Victoria', 'Tasmania']
# 📍 Venue: Junction Oval, Melbourne
# 📊 Score: [{'r': 256, 'w': 10, 'o': 90.5, 'inning': 'Victoria Inning 1'}, {'r': 232, 'w': 10, 'o': 80.4, 'inning': 'Tasmania Inning 1'}, {'r': 330, 'w': 5, 'o': 97, 'inning': 'Victoria Inning 2'}, {'r': 28, 'w': 1, 'o': 8, 'inning': 'Tasmania Inning 2'}]
# ----------------------------------------
# 📌 Match: Hobart Hurricanes Women vs Brisbane Heat Women, Final
# 🔄 Status: Hobart Hurricanes Women won by 88 runs
# 🆚 Teams: ['Hobart Hurricanes Women', 'Brisbane Heat Women']
# 📍 Venue: Cricket Central, Sydney
# 📊 Score: [{'r': 193, 'w': 4, 'o': 20, 'inning': 'Hobart Hurricanes Women Inning 1'}, {'r': 105, 'w': 10, 'o': 19, 'inning': 'Brisbane Heat Women Inning 1'}]
# ----------------------------------------
# 📌 Match: India A vs South Africa A, 1st Unofficial Test
# 🔄 Status: Day 1: 2nd Session - India A opt to bowl
# 🆚 Teams: ['India A', 'South Africa A']
# 📍 Venue: BCCI Centre of Excellence Ground 1, Bengaluru
# 📊 Score: [{'r': 153, 'w': 2, 'o': 39, 'inning': 'South Africa A Inning 1'}]
# ----------------------------------------
# 📌 Match: New Zealand vs England, 2nd ODI
# 🔄 Status: New Zealand won by 5 wkts
# 🆚 Teams: ['New Zealand', 'England']
# 📍 Venue: Seddon Park, Hamilton
# 📊 Score: [{'r': 175, 'w': 10, 'o': 36, 'inning': 'England Inning 1'}, {'r': 177, 'w': 5, 'o': 33.1, 'inning': 'New Zealand Inning 1'}]
# ----------------------------------------
# 📌 Match: England Women vs South Africa Women, 1st Semi-Final
# 🔄 Status: South Africa Women won by 125 runs
# 🆚 Teams: ['England Women', 'South Africa Women']
# 📍 Venue: Barsapara Cricket Stadium, Guwahati
# 📊 Score: [{'r': 319, 'w': 7, 'o': 50, 'inning': 'South Africa Women Inning 1'}, {'r': 194, 'w': 10, 'o': 42.3, 'inning': 'England Women Inning 1'}]
# ----------------------------------------
# 📌 Match: Australia vs India, 1st T20I
# 🔄 Status: No result (due to rain)
# 🆚 Teams: ['Australia', 'India']
# 📍 Venue: Manuka Oval, Canberra
# 📊 Score: [{'r': 97, 'w': 1, 'o': 9.4, 'inning': 'India Inning 1'}]
# ----------------------------------------
# 📌 Match: Auckland vs Otago, 6th Match
# 🔄 Status: Auckland won by 95 runs
# 🆚 Teams: ['Auckland', 'Otago']
# 📍 Venue: Eden Park Outer Oval, Auckland
# 📊 Score: [{'r': 232, 'w': 10, 'o': 47.5, 'inning': 'Auckland Inning 1'}, {'r': 137, 'w': 10, 'o': 31, 'inning': 'Otago Inning 1'}]
# ----------------------------------------
# 📌 Match: Central Districts vs Northern Knights, 5th Match
# 🔄 Status: Northern Knights won by 113 runs (DLS Method)
# 🆚 Teams: ['Central Districts', 'Northern Knights']
# 📍 Venue: Pukekura Park, New Plymouth
# 📊 Score: [{'r': 271, 'w': 8, 'o': 49, 'inning': 'Northern Knights Inning 1'}, {'r': 156, 'w': 10, 'o': 42.4, 'inning': 'Central Districts Inning 1'}]
# ----------------------------------------
# 📌 Match: Wellington vs Canterbury, 4th Match
# 🔄 Status: Wellington won by 2 wkts
# 🆚 Teams: ['Wellington', 'Canterbury']
# 📍 Venue: Basin Reserve, Wellington
# 📊 Score: [{'r': 258, 'w': 10, 'o': 49.5, 'inning': 'Canterbury Inning 1'}, {'r': 259, 'w': 8, 'o': 49, 'inning': 'Wellington Inning 1'}]
# ----------------------------------------
#
#
# 📊 Fetching cric scores...
#
# 📁 Saved to: cricket_results\cric_scores_2025-10-30_13-36-56.txt
#
# 🖥️ Output:
#
# 📈 CRIC SCORES
#
# 📌 Match: New Zealand [NZ] vs West Indies [WI]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 06, 06:15 GMT
# ----------------------------------------
# 📌 Match: India A [INA] vs South Africa A [SA-A]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 06, 03:30 GMT
# ----------------------------------------
# 📌 Match: Canada Women [CW] vs Tanzania Women [TAN-W]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 05, 06:30 GMT
# ----------------------------------------
# 📌 Match: New Zealand [NZ] vs West Indies [WI]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 05, 06:15 GMT
# ----------------------------------------
# 📌 Match: Pakistan [PAK] vs South Africa [RSA]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 04, 09:00 GMT
# ----------------------------------------
# 📌 Match: Canada Women [CW] vs Tanzania Women [TAN-W]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 04, 06:30 GMT
# ----------------------------------------
# 📌 Match: Bulgaria [BUL] vs Cyprus [CYP]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 03, 11:15 GMT
# ----------------------------------------
# 📌 Match: Bulgaria [BUL] vs Cyprus [CYP]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 03, 07:00 GMT
# ----------------------------------------
# 📌 Match: New South Wales [NSW] vs Queensland [QL]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 03, 23:00 GMT
# ----------------------------------------
# 📌 Match: Northern Knights [NK] vs Wellington [WEL]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 03, 21:30 GMT
# ----------------------------------------
# 📌 Match: Central Districts [CD] vs Otago [OTG]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 03, 21:30 GMT
# ----------------------------------------
# 📌 Match: Auckland [AKL] vs Canterbury [CAN]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 03, 21:30 GMT
# ----------------------------------------
# 📌 Match: Afghanistan [AFG] vs Zimbabwe [ZIM]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 02, 11:30 GMT
# ----------------------------------------
# 📌 Match: Afghanistan [AFG] vs Zimbabwe [ZIM]
# ⚡ Score: None
# 📝 Status: Match not started
# ----------------------------------------
# 📌 Match: Bulgaria [BUL] vs Cyprus [CYP]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 02, 11:05 GMT
# ----------------------------------------
# 📌 Match: Australia [AUS] vs India [IND]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 02, 08:15 GMT
# ----------------------------------------
# 📌 Match: Bulgaria [BUL] vs Cyprus [CYP]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 02, 07:00 GMT
# ----------------------------------------
# 📌 Match: Canada Women [CW] vs Tanzania Women [TAN-W]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 02, 06:30 GMT
# ----------------------------------------
# 📌 Match: Brazil [BRA] vs Mexico [MEX]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 02, 16:30 GMT
# ----------------------------------------
# 📌 Match: Pakistan [PAK] vs South Africa [RSA]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 15:00 GMT
# ----------------------------------------
# 📌 Match: Bulgaria [BUL] vs Serbia [SRB]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 11:15 GMT
# ----------------------------------------
# 📌 Match: Bulgaria [BUL] vs Serbia [SRB]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 07:00 GMT
# ----------------------------------------
# 📌 Match: Canada Women [CW] vs Tanzania Women [TAN-W]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 06:30 GMT
# ----------------------------------------
# 📌 Match: Jharkhand [JHKD] vs Nagaland [NGL]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Bengal [BEN] vs Tripura [TRI]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Tamil Nadu [TN] vs Vidarbha [VID]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Gujarat [GUJ] vs Haryana [HAR]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Bihar [BIH] vs Meghalaya [MGLY]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Mizoram [MIZ] vs Sikkim [SKM]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Arunachal Pradesh [ARNP] vs Manipur [MNP]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Goa [GOA] vs Punjab [PUN]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Mumbai [MUM] vs Rajasthan [RAJ]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Maharashtra [MAH] vs Saurashtra [SAUR]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Services [SER] vs Uttarakhand [UTK]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Karnataka [KAR] vs Kerala [KER]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Chhattisgarh [CG] vs Jammu and Kashmir [JK]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Himachal Pradesh [HP] vs Hyderabad [HYD]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Chandigarh [CDG] vs Madhya Pradesh [MP]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Delhi [DEL] vs Puducherry [PDC]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Baroda [BRD] vs Uttar Pradesh [UP]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Assam [ASM] vs Railways [RLYS]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: Andhra [AP] vs Odisha [ODSA]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 04:00 GMT
# ----------------------------------------
# 📌 Match: England [ENG] vs New Zealand [NZ]
# ⚡ Score: None
# 📝 Status: Match starts at Nov 01, 01:00 GMT
# ----------------------------------------
# 📌 Match: Pakistan [PAK] vs South Africa [RSA]
# ⚡ Score: None
# 📝 Status: Match starts at Oct 31, 15:00 GMT
# ----------------------------------------
# 📌 Match: Bangladesh [BAN] vs West Indies [WI]
# ⚡ Score: None
# 📝 Status: Match starts at Oct 31, 12:00 GMT
# ----------------------------------------
# 📌 Match: Brazil [BRA] vs Panama [PNM]
# ⚡ Score: None
# 📝 Status: Match starts at Oct 31, 12:00 GMT
# ----------------------------------------
# 📌 Match: Afghanistan [AFG] vs Zimbabwe [ZIM]
# ⚡ Score: None
# 📝 Status: Match not started
# ----------------------------------------
# 📌 Match: Afghanistan [AFG] vs Zimbabwe [ZIM]
# ⚡ Score: None
# 📝 Status: Match starts at Oct 31, 11:30 GMT
# ----------------------------------------
# 📌 Match: Cyprus [CYP] vs Serbia [SRB]
# ⚡ Score: None
# 📝 Status: Match starts at Oct 31, 11:15 GMT
# ----------------------------------------
# 📌 Match: Australia [AUS] vs India [IND]
# ⚡ Score: None
# 📝 Status: Match starts at Oct 31, 08:15 GMT
# ----------------------------------------
# 📌 Match: Cyprus [CYP] vs Serbia [SRB]
# ⚡ Score: None
# 📝 Status: Match starts at Oct 31, 07:00 GMT
# ----------------------------------------
# 📌 Match: Mexico [MEX] vs Panama [PNM]
# ⚡ Score: None
# 📝 Status: Match starts at Oct 30, 16:30 GMT
# ----------------------------------------
# 📌 Match: Australia Women [AUSW] vs India Women [INDW]
# ⚡ Score: None
# 📝 Status: Match starts at Oct 30, 09:30 GMT
# ----------------------------------------
# 📌 Match: Canada Women [CW] vs Tanzania Women [TAN-W]
# ⚡ Score: None
# 📝 Status: Match starts at Oct 30, 06:30 GMT
# ----------------------------------------
# 📌 Match: India A [INA] vs South Africa A [SA-A]
# ⚡ Score: None
# 📝 Status: Day 1: 2nd Session - India A opt to bowl
# ----------------------------------------
# 📌 Match: Brisbane Heat Women [BH-W] vs Hobart Hurricanes Women [HB-W]
# ⚡ Score: None
# 📝 Status: Hobart Hurricanes Women won by 88 runs
# ----------------------------------------
# 📌 Match: Canterbury [CAN] vs Wellington [WEL]
# ⚡ Score: None
# 📝 Status: Wellington won by 2 wkts
# ----------------------------------------
# 📌 Match: Auckland [AKL] vs Otago [OTG]
# ⚡ Score: None
# 📝 Status: Auckland won by 95 runs
# ----------------------------------------
# 📌 Match: Central Districts [CD] vs Northern Knights [NK]
# ⚡ Score: None
# 📝 Status: Northern Knights won by 113 runs (DLS Method)
# ----------------------------------------
# 📌 Match: Bangladesh [BAN] vs West Indies [WI]
# ⚡ Score: None
# 📝 Status: West Indies won by 14 runs
# ----------------------------------------
# 📌 Match: Afghanistan [AFG] vs Zimbabwe [ZIM]
# ⚡ Score: None
# 📝 Status: Match starts at Jan 01, 00:00 GMT
# ----------------------------------------
# 📌 Match: Afghanistan [AFG] vs Zimbabwe [ZIM]
# ⚡ Score: None
# 📝 Status: Afghanistan won by 53 runs
# ----------------------------------------
# 📌 Match: England Women [ENGW] vs South Africa Women [RSAW]
# ⚡ Score: None
# 📝 Status: South Africa Women won by 125 runs
# ----------------------------------------
# 📌 Match: Australia [AUS] vs India [IND]
# ⚡ Score: None
# 📝 Status: No result (due to rain)
# ----------------------------------------
# 📌 Match: Brisbane Heat Women [BH-W] vs Melbourne Renegades Women [MR-W]
# ⚡ Score: None
# 📝 Status: Match abandoned without a ball bowled due to rain (No toss)
# ----------------------------------------
# 📌 Match: England [ENG] vs New Zealand [NZ]
# ⚡ Score: None
# 📝 Status: New Zealand won by 5 wkts
# ----------------------------------------
# 📌 Match: Hobart Hurricanes Women [HB-W] vs Perth Scorchers Women [PS-W]
# ⚡ Score: None
# 📝 Status: Match abandoned without a ball bowled due to rain ( No toss)
# ----------------------------------------
# 📌 Match: Pakistan [PAK] vs South Africa [RSA]
# ⚡ Score: None
# 📝 Status: South Africa won by 55 runs
# ----------------------------------------
# 📌 Match: South Australia [SAUS] vs Western Australia [WA]
# ⚡ Score: None
# 📝 Status: Day 3: Tea Break - South Australia lead by 89 runs
# ----------------------------------------
# 📌 Match: New South Wales [NSW] vs Queensland [QL]
# ⚡ Score: None
# 📝 Status: Day 3: 3rd Session - Queensland trail by 201 runs
# ----------------------------------------
# 📌 Match: Tasmania [TAS] vs Victoria [VIC]
# ⚡ Score: None
# 📝 Status: Day 3: Stumps - Tasmania need 327 runs
# ----------------------------------------
# 📌 Match: Bangladesh [BAN] vs West Indies [WI]
# ⚡ Score: None
# 📝 Status: West Indies won by 16 runs
# ----------------------------------------
# 📌 Match: Act Women [ACTW] vs Melbourne Renegades Women [MR-W]
# ⚡ Score: None
# 📝 Status: Melbourne Renegades Women won by 3 wkts
# ----------------------------------------
# 📌 Match: Melbourne Stars Women [MS-W] vs Perth Scorchers Women [PS-W]
# ⚡ Score: None
# 📝 Status: Perth Scorchers Women won by 52 runs
# ----------------------------------------
# 📌 Match: Canada Women [CW] vs Uganda Women [UGAW]
# ⚡ Score: None
# 📝 Status: Uganda Women won by 12 runs
# ----------------------------------------
# 📌 Match: Bangladesh Women [BANW] vs India Women [INDW]
# ⚡ Score: None
# 📝 Status: No result  -  due to rain
# ----------------------------------------
# 📌 Match: Nepal [NEP] vs United States of America [US]
# ⚡ Score: None
# 📝 Status: United States of America won by 106 runs
# ----------------------------------------
# 📌 Match: England Women [ENGW] vs New Zealand Women [NZW]
# ⚡ Score: None
# 📝 Status: England Women won by 8 wkts
# ----------------------------------------
# 📌 Match: Melbourne Renegades Women [MR-W] vs Sydney Sixers Women [SS-W]
# ⚡ Score: None
# 📝 Status: Melbourne Renegades Women won by 32 runs
# ----------------------------------------
# 📌 Match: Adelaide Strikers Women [AS-W] vs Sydney Thunder Women [ST-W]
# ⚡ Score: None
# 📝 Status: Sydney Thunder Women won by 8 wkts
# ----------------------------------------
# 📌 Match: England [ENG] vs New Zealand [NZ]
# ⚡ Score: None
# 📝 Status: New Zealand won by 4 wkts
# ----------------------------------------
# 📌 Match: Brisbane Heat Women [BH-W] vs Hobart Hurricanes Women [HB-W]
# ⚡ Score: None
# 📝 Status: Hobart Hurricanes Women won by 8 wkts
# ----------------------------------------
# 📌 Match: Act Women [ACTW] vs Perth Scorchers Women [PS-W]
# ⚡ Score: None
# 📝 Status: Perth Scorchers Women won by 4 runs (DLS Method)
# ----------------------------------------
# 📌 Match: Australia Women [AUSW] vs South Africa Women [RSAW]
# ⚡ Score: None
# 📝 Status: Australia Women won by 7 wkts
# ----------------------------------------
# 📌 Match: Meghalaya [MGLY] vs Sikkim [SKM]
# ⚡ Score: None
# 📝 Status: Match drawn
# ----------------------------------------
# 📌 Match: Bihar [BIH] vs Manipur [MNP]
# ⚡ Score: None
# 📝 Status: Match drawn
# ----------------------------------------
# 📌 Match: Arunachal Pradesh [ARNP] vs Mizoram [MIZ]
# ⚡ Score: None
# 📝 Status: Day 4: 3rd Session - Arunachal Pradesh trail by 108 runs
# ----------------------------------------
# 📌 Match: Bengal [BEN] vs Gujarat [GUJ]
# ⚡ Score: None
# 📝 Status: Day 4: 3rd Session - Gujarat need 146 runs
# ----------------------------------------
# 📌 Match: Delhi [DEL] vs Himachal Pradesh [HP]
# ⚡ Score: None
# 📝 Status: Match drawn
# ----------------------------------------
# 📌 Match: Assam [ASM] vs Services [SER]
# ⚡ Score: None
# 📝 Status: Services won by 8 wkts
# ----------------------------------------
# 📌 Match: Goa [GOA] vs Karnataka [KAR]
# ⚡ Score: None
# 📝 Status: Match drawn
# ----------------------------------------
# 📌 Match: Haryana [HAR] vs Tripura [TRI]
# ⚡ Score: None
# 📝 Status: Haryana won by 9 wkts
# ----------------------------------------
# 📌 Match: Madhya Pradesh [MP] vs Saurashtra [SAUR]
# ⚡ Score: None
# 📝 Status: Match drawn
# ----------------------------------------
# 📌 Match: Chhattisgarh [CG] vs Mumbai [MUM]
# ⚡ Score: None
# 📝 Status: Match drawn
# ----------------------------------------
# 📌 Match: Railways [RLYS] vs Uttarakhand [UTK]
# ⚡ Score: None
# 📝 Status: Day 4: Tea Break - Railways lead by 20 runs
# ----------------------------------------
# 📌 Match: Jharkhand [JHKD] vs Vidarbha [VID]
# ⚡ Score: None
# 📝 Status: Match drawn
# ----------------------------------------
# 📌 Match: Jammu and Kashmir [JK] vs Rajasthan [RAJ]
# ⚡ Score: None
# 📝 Status: Jammu and Kashmir won by an innings and 41 runs
# ----------------------------------------
# 📌 Match: Andhra [AP] vs Baroda [BRD]
# ⚡ Score: None
# 📝 Status: Match drawn
# ----------------------------------------
# 📌 Match: Kerala [KER] vs Punjab [PUN]
# ⚡ Score: None
# 📝 Status: Day 4: Tea Break - Punjab lead by 80 runs
# ----------------------------------------
# 📌 Match: Nagaland [NGL] vs Tamil Nadu [TN]
# ⚡ Score: None
# 📝 Status: Match drawn
# ----------------------------------------
# 📌 Match: Odisha [ODSA] vs Uttar Pradesh [UP]
# ⚡ Score: None
# 📝 Status: Match drawn
# ----------------------------------------
# 📌 Match: Hyderabad [HYD] vs Puducherry [PDC]
# ⚡ Score: None
# 📝 Status: Match drawn
# ----------------------------------------
# 📌 Match: Chandigarh [CDG] vs Maharashtra [MAH]
# ⚡ Score: None
# 📝 Status: Day 4: 3rd Session - Chandigarh need 157 runs
# ----------------------------------------
# 📌 Match: Australia [AUS] vs India [IND]
# ⚡ Score: None
# 📝 Status: India won by 9 wkts
# ----------------------------------------
# 📌 Match: Sydney Sixers Women [SS-W] vs Sydney Thunder Women [ST-W]
# ⚡ Score: None
# 📝 Status: Sydney Sixers Women won by 24 runs
# ----------------------------------------
# 📌 Match: Brisbane Heat Women [BH-W] vs Melbourne Stars Women [MS-W]
# ⚡ Score: None
# 📝 Status: Brisbane Heat Women won by 63 runs
# ----------------------------------------
# 📌 Match: Canterbury [CAN] vs Otago [OTG]
# ⚡ Score: None
# 📝 Status: Canterbury won by 6 wkts
# ----------------------------------------
# 📌 Match: Central Districts [CD] vs Wellington [WEL]
# ⚡ Score: None
# 📝 Status: Central Districts won by 4 wkts
# ----------------------------------------
# 📌 Match: Auckland [AKL] vs Northern Knights [NK]
# ⚡ Score: None
# 📝 Status: Auckland won by 6 wkts
# ----------------------------------------
# 📌 Match: Canada Women [CW] vs Uganda Women [UGAW]
# ⚡ Score: None
# 📝 Status: Uganda Women won by 43 runs
# ----------------------------------------
# 📌 Match: Pakistan Women [PAKW] vs Sri Lanka Women [SLW]
# ⚡ Score: None
# 📝 Status: No result (due to rain)
# ----------------------------------------
# 📌 Match: Adelaide Strikers Women [AS-W] vs Melbourne Renegades Women [MR-W]
# ⚡ Score: None
# 📝 Status: Melbourne Renegades Women won by 7 wkts
# ----------------------------------------
# 📌 Match: Hobart Hurricanes Women [HB-W] vs Melbourne Stars Women [MS-W]
# ⚡ Score: None
# 📝 Status: Hobart Hurricanes Women won by 6 wkts
# ----------------------------------------
# 📌 Match: India Women [INDW] vs New Zealand Women [NZW]
# ⚡ Score: None
# 📝 Status: India Women won by 53 runs (DLS Method)
# ----------------------------------------
# 📌 Match: Canada Women [CW] vs Uganda Women [UGAW]
# ⚡ Score: None
# 📝 Status: Uganda Women won by 18 runs
# ----------------------------------------
#
#
# 🕓 Fetching past matches...
#
# 📁 Saved to: cricket_results\past_matches_2025-10-30_13-37-01.txt
#
# 🖥️ Output:
#
# 📜 PAST MATCHES
#
# 📌 Match: Nepal vs United States of America, 86th Match
# 📅 Date: 2025-10-26
# ✅ Status: United States of America won by 106 runs
# ----------------------------------------
# 📌 Match: Brazil vs Mexico, 3rd Match
# 📅 Date: 2025-11-01
# ✅ Status: Match starts at Nov 02, 16:30 GMT
# ----------------------------------------
# 📌 Match: Brazil vs Panama, 2nd Match
# 📅 Date: 2025-10-31
# ✅ Status: Match starts at Oct 31, 12:00 GMT
# ----------------------------------------
# 📌 Match: Panama vs Mexico, 1st Match
# 📅 Date: 2025-10-30
# ✅ Status: Match starts at Oct 30, 16:30 GMT
# ----------------------------------------
# 📌 Match: Thailand Women vs Papua New Guinea Women, 6th Match
# 📅 Date: 2025-11-17
# ✅ Status: Match starts at Nov 17, 06:30 GMT
# ----------------------------------------
# 📌 Match: Scotland Women vs Namibia Women, 5th Match
# 📅 Date: 2025-11-17
# ✅ Status: Match starts at Nov 17, 02:00 GMT
# ----------------------------------------
# 📌 Match: Thailand Women vs Scotland Women, 4th Match
# 📅 Date: 2025-11-15
# ✅ Status: Match starts at Nov 15, 06:30 GMT
# ----------------------------------------
# 📌 Match: Namibia Women vs Papua New Guinea Women, 3rd Match
# 📅 Date: 2025-11-15
# ✅ Status: Match starts at Nov 15, 02:00 GMT
# ----------------------------------------
# 📌 Match: Thailand Women vs Namibia Women, 2nd Match
# 📅 Date: 2025-11-14
# ✅ Status: Match starts at Nov 14, 06:30 GMT
# ----------------------------------------
# 📌 Match: Scotland Women vs Papua New Guinea Women, 1st Match
# 📅 Date: 2025-11-14
# ✅ Status: Match starts at Nov 14, 02:00 GMT
# ----------------------------------------
# 📌 Match: Papua New Guinea Women vs United Arab Emirates Women, 4th ODI
# 📅 Date: 2025-10-19
# ✅ Status: Papua New Guinea Women won by 78 runs
# ----------------------------------------
# 📌 Match: Uganda Women vs Canada Women, 5th T20I
# 📅 Date: 2025-10-26
# ✅ Status: Uganda Women won by 12 runs
# ----------------------------------------
# 📌 Match: Uganda Women vs Canada Women, 4th T20I
# 📅 Date: 2025-10-24
# ✅ Status: Uganda Women won by 43 runs
# ----------------------------------------
# 📌 Match: Romania vs Austria, 4th T20I
# 📅 Date: 2025-10-19
# ✅ Status: Austria won by 42 runs
# ----------------------------------------
# 📌 Match: Romania vs Austria, 3rd T20I
# 📅 Date: 2025-10-19
# ✅ Status: Austria won by 7 wkts
# ----------------------------------------
# 📌 Match: Papua New Guinea Women vs United Arab Emirates Women, 3rd ODI
# 📅 Date: 2025-10-17
# ✅ Status: United Arab Emirates Women won by 160 runs
# ----------------------------------------
# 📌 Match: Uganda Women vs Canada Women, 3rd T20I
# 📅 Date: 2025-10-23
# ✅ Status: Uganda Women won by 18 runs
# ----------------------------------------
# 📌 Match: Uganda Women vs Canada Women, 2nd T20I
# 📅 Date: 2025-10-21
# ✅ Status: Uganda Women won by 4 wkts
# ----------------------------------------
# 📌 Match: Uganda Women vs Canada Women, 1st T20I
# 📅 Date: 2025-10-20
# ✅ Status: Uganda Women won by 7 wkts
# ----------------------------------------
# 📌 Match: Papua New Guinea Women vs United Arab Emirates Women, 2nd ODI
# 📅 Date: 2025-10-15
# ✅ Status: Papua New Guinea Women won by 3 wkts
# ----------------------------------------
# 📌 Match: Papua New Guinea Women vs United Arab Emirates Women, 1st ODI
# 📅 Date: 2025-10-12
# ✅ Status: United Arab Emirates Women won by 5 wkts
# ----------------------------------------
# 📌 Match: Romania vs Austria, 2nd T20I
# 📅 Date: 2025-10-18
# ✅ Status: Romania won by 3 wkts
# ----------------------------------------
# 📌 Match: Romania vs Austria, 1st T20I
# 📅 Date: 2025-10-18
# ✅ Status: Austria won by 4 wkts
# ----------------------------------------
# 📌 Match: Pakistan vs South Africa, 3rd ODI
# 📅 Date: 2025-11-08
# ✅ Status: Match starts at Nov 08, 09:00 GMT
# ----------------------------------------
# 📌 Match: Pakistan vs South Africa, 2nd ODI
# 📅 Date: 2025-11-06
# ✅ Status: Match starts at Nov 06, 09:00 GMT
# ----------------------------------------
